# %% [markdown]
# <a href="https://www.kaggle.com/code/mikematician/neural-ode-continious-normalizing-flow?scriptVersionId=313848356" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a href="https://www.kaggle.com/code/mikematician/neural-ode-continious-normalizing-flow?scriptVersionId=313689071" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Neural ODE / Continious Normalizing Flow from Scratch

# %% [markdown]
# try:
# - smaller regularization
# - smaller model
# - more training steps

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchinfo import summary

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles, make_moons

# if nvidia gpu available use it
device = "cuda" if torch.cuda.is_available() else "cpu"

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("Device:", torch.cuda.get_device_name(0))
    print("Compute capability:", torch.cuda.get_device_capability(0))
    print("Supported archs:", torch.cuda.get_arch_list())
# Out:
# PyTorch: 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8
# Device: Tesla T4
# Compute capability: (7, 5)
# Supported archs: ['sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']

# %% [markdown]
# ## 1. Generate Toy Datasets

# %%
# generate moon dataset
coord_moon, label_moon = make_moons(1000, noise=0.025)

# generate circle dataset 
coord_circle, label_circle = make_circles(1000, noise=0.025, factor=0.5)

# dtype of dataset
print(type(coord_circle))

# dimension of data
print(coord_circle.shape)
print(label_circle.shape)

print(coord_circle[0])
# Out:
# <class 'numpy.ndarray'>
# (1000, 2)
# (1000,)
# [ 0.38236347 -0.2719431 ]

# %%
# plot datasets
fig, ax = plt.subplots(1, 2, figsize=(14, 7))

# plot circle data
ax[0].scatter(coord_circle[... , 0], coord_circle[... , 1], s=1, c=label_circle, cmap="berlin")

# plot moon data
ax[1].scatter(coord_moon[... , 0], coord_moon[... , 1], s=1, c=label_moon, cmap="berlin")

# %%
# Turn circle data into tensor dataset
x_circle = coord_circle[..., 0]
y_circle = coord_circle[..., 1]

circle_numpy = np.array([x_circle, y_circle])
circle_tensor = torch.from_numpy(circle_numpy).float().T
print(circle_tensor.shape)

# Turn moon data into tensor dataset
x_moon = coord_moon[..., 0]
y_moon = coord_moon[..., 1]

moon_numpy = np.array([x_moon, y_moon])
moon_tensor = torch.from_numpy(moon_numpy).float().T
print(moon_tensor.shape)
# Out:
# torch.Size([1000, 2])
# torch.Size([1000, 2])

# %% [markdown]
# ## 2. ODE-Solver

# %% [markdown]
# ### 2.1 Euler Method

# %%
# one step of euler method
def euler_step(dynamic, y_n, t_n, step_size):
    step = y_n + step_size * dynamic(y_n, t_n)
    return step


# euler ode solver
def euler_solver(dynamic, y_0, t_0, nb_steps, step_size):
    y_n, t_n = y_0, t_0

    # calculate steps until endstep
    for _ in range(nb_steps):
        y_n = euler_step(dynamic, y_n, t_n, step_size)
        t_n = t_n + step_size
    
    return y_n, t_n

# %% [markdown]
# ### 2.2 Runge-Kutta method (RK4)

# %%
# one step of Runge-Kutta (RK4)
def rk4_step(dynamic, y_n, t_n, stepsize):
    # calculate k_n for n in [1, 2, 3, 4] for weighted average of the four increments
    k_1 = dynamic(y_n, t_n)
    k_2 = dynamic(y_n + k_1 * stepsize / 2, t_n + stepsize / 2)
    k_3 = dynamic(y_n + k_2 * stepsize / 2, t_n + stepsize / 2)
    k_4 = dynamic(y_n + stepsize * k_3, t_n + stepsize)

    # calculate step
    step = y_n + stepsize / 6 * (k_1 + 2*k_2 + 2*k_3 + k_4)
    return step

# Runge-Kutta ode solver
def rk4_solver(model, y_0, t_0, nb_steps, step_size):
    y_n, t_n = y_0, t_0

    # calculate steps until endstep
    for _ in range(nb_steps):
        y_n = rk4_step(model, y_n, t_n, step_size)
        t_n = t_n + step_size
    
    return y_n, t_n

# %% [markdown]
# ### 2.3 Test ODE Solver

# %%
# analytical solution
# dy/dt = -y, y(t) = y_0 * exp(-t)
# dy/dt = 2t, y(t) = y_0 + t^2

def model_exp(y, t):
    """dy/dt = -y"""
    return -y

def model_linear(y, t):
    """dy/dt = 2"""
    return 2

# %%
# testing euler 
# case exp decay
y_0_exp = torch.tensor(1.0)
y_end_exp = euler_solver(model_exp, y_0_exp, t_0=0.0, nb_steps=1000, step_size=0.001)
expected_exp = torch.exp(torch.tensor(-1.0))

# case linear function
y_0_linear = torch.tensor(1.0)
y_end_linear = euler_solver(model_linear, y_0_linear, t_0=0.0, nb_steps=1000, step_size=0.001)
expected_linear = y_0_linear + 2

# case 2D input
y_0_2D = torch.ones(8, 2)
y_end_2D = euler_solver(model_exp, y_0_2D, t_0=0.0, nb_steps=10, step_size=0.1)

print(f"exp true: {expected_exp}, solver: {y_end_exp}")
print(f"linear true: {expected_linear}, solver: {y_end_linear}")
print(f"solver 2D: {y_end_2D}")
# Out:
# exp true: 0.3678794503211975, solver: (tensor(0.3677), 1.0000000000000007)
# linear true: 3.0, solver: (tensor(3.0000), 1.0000000000000007)
# solver 2D: (tensor([[0.3487, 0.3487],
#         [0.3487, 0.3487],
#         [0.3487, 0.3487],
#         [0.3487, 0.3487],
#         [0.3487, 0.3487],
#         [0.3487, 0.3487],
#         [0.3487, 0.3487],
#         [0.3487, 0.3487]]), 0.9999999999999999)

# %%
# testing rk4 
# case exp decay
y_0_exp = torch.tensor(1.0)
y_end_exp = rk4_solver(model_exp, y_0_exp, t_0=0.0, nb_steps=1000, step_size=0.001)
expected_exp = torch.exp(torch.tensor(-1.0))

# case linear function
y_0_linear = torch.tensor(1.0)
y_end_linear = rk4_solver(model_linear, y_0_linear, t_0=0.0, nb_steps=1000, step_size=0.001)
expected_linear = y_0_linear + 2

# case 2D input
y_0_2D = torch.ones(8, 2)
y_end_2D = rk4_solver(model_exp, y_0_2D, t_0=0.0, nb_steps=10, step_size=0.1)

print(f"exp true: {expected_exp}, solver: {y_end_exp}")
print(f"linear true: {expected_linear}, solver: {y_end_linear}")
print(f"solver 2D: {y_end_2D}")
# Out:
# exp true: 0.3678794503211975, solver: (tensor(0.3679), 1.0000000000000007)
# linear true: 3.0, solver: (tensor(3.0000), 1.0000000000000007)
# solver 2D: (tensor([[0.3679, 0.3679],
#         [0.3679, 0.3679],
#         [0.3679, 0.3679],
#         [0.3679, 0.3679],
#         [0.3679, 0.3679],
#         [0.3679, 0.3679],
#         [0.3679, 0.3679],
#         [0.3679, 0.3679]]), 0.9999999999999999)

# %% [markdown]
# ## 3. Adjoint-based Backpropagation

# %% [markdown]
# ### 3.1 Custom Autograd Function for Adjoint Method

# %%
# custom autograd.Function s.t. pytorch does not calculate computational graph for autograd
class AdjointSolver(torch.autograd.Function):

    # to make calculation of trace cheaper and more stable we use vjp and Hutchinson-Trace-Estimation (Monte-Carlo-Mothod)
    @staticmethod
    def hutchinson_trace_estimate(dz_dt, z, n_samples=1, create_graph=False, retain_graph=False):
        trace = torch.zeros(z.shape[0], device=z.device)
        for i in range(n_samples):
            v = torch.ones_like(z)
            v[torch.rand_like(z) < 0.5] = -1
            keep = True if i < n_samples - 1 else retain_graph
            vjp = torch.autograd.grad(dz_dt, z, grad_outputs=v, create_graph=create_graph, retain_graph=keep)[0]
            trace += (vjp * v).sum(dim=-1)
        return trace / n_samples


    # create function to build system of ODEs
    @staticmethod
    def _augmented_dynamics(model, state, t, batch_size, detach_output=True):
        z_0 = state[:, :-1]

        # calculate gradient for trace
        with torch.enable_grad():
            if detach_output:
                z = z_0.detach().requires_grad_(True)
            else:
                z = z_0 if z_0.requires_grad else z_0.requires_grad_(True)          
            dz_dt = model(z, t)
            
            # normal trace calculation
            #grad_trace = torch.zeros(batch_size, device=z.device)
            #for i in range(dz_dt.shape[1]):
            #    grad = torch.autograd.grad(dz_dt[:, i].sum(), z, retain_graph=True, create_graph=not detach_output)[0]
            #    grad_trace = grad_trace + grad[:, i]
            
            # hurchinsin trace estimation
            grad_trace = AdjointSolver.hutchinson_trace_estimate(dz_dt, z, create_graph=not detach_output, retain_graph=not detach_output)
                
            F = torch.cat([dz_dt, -grad_trace.unsqueeze(1)], dim=1)
        
        if detach_output:
            return F.detach()
        else:
            return F 


    # forward pass through the vectorfield-model
    @staticmethod
    def forward(ctx, model, y_0, t_0, t_end, nb_steps, solver, *params):
        # calculate stepsize
        step_size = (t_end - t_0) / nb_steps

        batch_size = y_0.shape[0]

        # define state vector for initial problem with start of function and start of probability
        #log_p_0 = torch.log(distr(y_0))    # removed because for MLE we need backward direction and using this has no meaning. therefore just learning difference in probability is better
        delta_log_p_0 = torch.zeros(batch_size, 1, device=y_0.device)
        s_0 = torch.cat([y_0, delta_log_p_0], dim=1)

        def forward_dynamics(state, t):
            return AdjointSolver._augmented_dynamics(model, state, t, batch_size, detach_output=True)

        # solve initial value problem
        s_end = solver(forward_dynamics, s_0, t_0, nb_steps, step_size)[0]

        # safe variables for backward step
        ctx.model = model
        ctx.save_for_backward(s_end, s_0, y_0)
        ctx.t_0 = t_0
        ctx.t_end = t_end
        ctx.nb_steps = nb_steps
        ctx.solver = solver
        ctx.batch_size = batch_size

        return s_end
    

    # backward pass with adjoint vectorfield to get derivative of loss in respect to param of model
    @staticmethod
    def backward(ctx, dL_ds):
        # import saved variables from forwardpass
        model = ctx.model
        s_end, s_0, y_0, = ctx.saved_tensors
        t_0 = ctx.t_0
        t_end = ctx.t_end
        nb_steps = ctx.nb_steps
        solver = ctx.solver
        batch_size = ctx.batch_size

        # define state vector for initial problem with backwart y dynamic, adjoint dynamic and Loss-grad dynamic
        num_params = sum(p.numel() for p in model.parameters())
        a_end = dL_ds.detach()
        y_end = s_end.detach()
        h_0 = torch.cat([y_end, a_end, torch.zeros(batch_size, num_params, device=y_end.device)], dim=1)

        # calculate lenght of individual dynamics state
        lenght_a = a_end.shape[1]
        lenght_y = y_end.shape[1]

        def cat_dynamics(state, t):
            # define the states
            z_0 = state[:, :lenght_y]
            a_0 = state[:, lenght_y:lenght_y + lenght_a]

            # calculate gradients
            with torch.enable_grad():
                z = z_0.detach().requires_grad_(True)
                dz_dt = AdjointSolver._augmented_dynamics(model, z, t, batch_size, detach_output=False)

                # calculate the ODEs
                da_dt = -torch.autograd.grad(dz_dt, z, grad_outputs=a_0, retain_graph=True)[0]
                grad_params = torch.autograd.grad(dz_dt, model.parameters(), grad_outputs=a_0, retain_graph=True, allow_unused=True)
                # Result tuple of tensors in param shape --> flatten and concat
                flat_parts = []
                for p, g in zip(model.parameters(), grad_params):
                    if g is None:
                        flat_parts.append(torch.zeros(p.numel(), device=z.device))
                    else:
                        flat_parts.append(g.contiguous().flatten())
                dL_dparam = -torch.cat(flat_parts)

                # Broadcast to (batch_size, num_params) so shapes match the augmented state
                dL_dparam_batched = dL_dparam.unsqueeze(0).expand(batch_size, -1)
            
            return torch.cat([dz_dt.detach(), da_dt.detach(), dL_dparam_batched.detach()], dim=1)
        
        # calculate stepsize
        step_size = (t_0 - t_end) / nb_steps

        # solve initial value problem of cat augmented
        h_end = solver(cat_dynamics, h_0, t_end, nb_steps, step_size)[0]

        dy0_dt_full = h_end[:, :lenght_y]
        dy0_dt = dy0_dt_full[:, :-1]
        dL_dparam = h_end[0, lenght_y + lenght_a:]

        # safe gradients of Loss
        idx = 0
        for param in model.parameters():
            # reshape into param shape
            n = param.numel()
            dif = dL_dparam[idx:idx+n].reshape(param.shape)

            # update gradients
            if param.grad is None:
                param.grad = dif.clone()
            else:
                param.grad += dif
            idx+=n
        
        # check if all params have grad now
        assert (idx == len(dL_dparam))

        num_params = sum(1 for _ in model.parameters())

        # return all gradients of forward inputs
        return (None, dy0_dt, None, None, None, None) + (None,) * num_params

# %% [markdown]
# ### 3.2 Test Parts of Custom Autograd Function

# %%
# test function
W = torch.tensor([[1.0, 2.0], [3.0, 4.0]], requires_grad=True)
x = torch.randn(2, 1, requires_grad=True)
a_0 = torch.tensor([[1.0],[2.0]])

print(W.shape, x.shape)

def f(z, t):
    return W**2 @ z
# Out:
# torch.Size([2, 2]) torch.Size([2, 1])

# %%
# test forward dynamics
def cat_dynamics(state, t):
    z_0 = state #removed slicing because for testing not needed

    # calculate gradient for trace
    with torch.enable_grad():
        z = z_0.requires_grad_(True)
        dz_dt = f(z, t)

        grad_trace = 0
        for i in range(len(dz_dt)):
            grad_trace += torch.autograd.grad(dz_dt[i], z, retain_graph=True)[0][i]
                
    return torch.cat([dz_dt.detach(), -grad_trace.unsqueeze(0)])

# calculate trace of jacobian
trace_grad_f = cat_dynamics(x, 0)[-1]

print("== trace ==")
print(f"-tr(W): {(-W**2).trace()}")
print(f"cat_dynamic: {trace_grad_f}")
# Out:
# == trace ==
# -tr(W): -17.0
# cat_dynamic: tensor([-17.])

# %%
# test shapes
x = torch.randn(2, 1)
y = torch.rand(1, 2)

print(x)
print(y)
# Out:
# tensor([[-0.1366],
#         [ 1.2184]])
# tensor([[0.3641, 0.2860]])

# %%
# test backward dynamic

def cat_dynamics(state, t):
    # define the states
    z_0 = state # removed slicing because for testing not needed

    # calculate gradients
    with torch.enable_grad():
        z = z_0.detach().requires_grad_(True)
        dz_dt = f(z, t)

        # calculate the ODEs
        da_dt = -torch.autograd.grad(dz_dt, z, grad_outputs=a_0, retain_graph=True)[0]
        dL_dparam = torch.autograd.grad(dz_dt, [W], grad_outputs=a_0, retain_graph=True)
        dL_dparam = -torch.cat([g.flatten() for g in dL_dparam])
            
    return torch.cat([-dz_dt.detach().flatten(), da_dt.detach().flatten(), dL_dparam.detach().flatten()])

gradients = cat_dynamics(x, 0)
dz_adj  = gradients[:2]        # -dz/dt
da_adj  = gradients[2:4]       # da/dt
dW_adj  = gradients[4:]        # dL/dW flat

# calculate refrence directly with pytorch
z_ref = x.detach().requires_grad_(True)
W_ref = W.detach().requires_grad_(True)

dz_dt_ref = W_ref**2 @ z_ref   # shape [2,1]

loss = (a_0 * dz_dt_ref).sum()
loss.backward()

dz_ref = z_ref.grad.flatten()   # dL/dz
dW_ref = W_ref.grad.flatten()   # dL/dW

print("=== da/dt ===")
print(f"cat_dynamic:  {da_adj}")
print(f"Autograd: {-dz_ref}")
print(f"error: {(da_adj - (-dz_ref)).abs().max():.6f}")
print()

print("=== dL/dW ===")
print(f"cat_dynamic:  {dW_adj}")
print(f"Autograd: {-dW_ref}")
print(f"error: {(dW_adj - (-dW_ref)).abs().max():.6f}")
# Out:
# === da/dt ===
# cat_dynamic:  tensor([-19., -36.])
# Autograd: tensor([-19., -36.])
# error: 0.000000
#
# === dL/dW ===
# cat_dynamic:  tensor([  0.2731,  -4.8736,   1.6387, -19.4942])
# Autograd: tensor([  0.2731,  -4.8736,   1.6387, -19.4942])
# error: 0.000000

# %%
# test adjoint
# small test network
class DynamicsNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(2, 16),
            nn.Tanh(),
            nn.Linear(16, 2)
        )
    
    def forward(self, z, t):
        return self.net(z)  # t wird ignoriert, aber Signatur stimmt

model = DynamicsNet()

# test data
torch.manual_seed(42)
batch_size = 8
y_0 = torch.randn(batch_size, 2)
t_0    = 0.0
t_end  = 1.0
nb_steps = 100

def nll_from_state(s_end):
    z_T        = s_end[:, :-1]           
    delta_logp = s_end[:, -1]            
    log_p_z    = -0.5 * (z_T ** 2).sum(dim=-1) - z_T.shape[1] * 0.5 * torch.log(torch.tensor(2 * torch.pi))
    log_p_x    = log_p_z + delta_logp
    return -log_p_x.mean()

# 1) DIRECT BACKPROP
model.zero_grad()

# Augmented dynamics
def augmented_dynamics_direct(state, t):
    return AdjointSolver._augmented_dynamics(model, state, t, batch_size, detach_output=False)

step_size_fwd = (t_end - t_0) / nb_steps
delta_log_p_0 = torch.zeros(batch_size, 1)
s_0 = torch.cat([y_0, delta_log_p_0], dim=1)

s_end_direct = rk4_solver(augmented_dynamics_direct, s_0, t_0, nb_steps, step_size_fwd)[0]

loss_direct = nll_from_state(s_end_direct)
loss_direct.backward()

# gradients
grads_direct = [p.grad.clone() for p in model.parameters()]

# 2) MY ADJOINT
model.zero_grad()

params = list(model.parameters())
s_end_adjoint = AdjointSolver.apply(model, y_0, t_0, t_end, nb_steps, rk4_solver, *params)

loss_adjoint = nll_from_state(s_end_adjoint)
loss_adjoint.backward()

grads_adjoint = [p.grad.clone() for p in model.parameters()]

# Comparison
print("=== Gradient Comparison ===")
all_close = True
for i, (g_d, g_a) in enumerate(zip(grads_direct, grads_adjoint)):
    max_err = (g_d - g_a).abs().max().item()
    rel_err = ((g_d - g_a).abs() / (g_d.abs() + 1e-8)).max().item()
    close   = torch.allclose(g_d, g_a, atol=1e-4)
    all_close = all_close and close
    print(f"  Param {i:2d} | max abs err: {max_err:.2e} | max rel err: {rel_err:.2e} | allclose: {close}")

print()
print(f"  Loss direct:  {loss_direct.item():.6f}")
print(f"  Loss adjoint: {loss_adjoint.item():.6f}")
print(f"  Losses match: {abs(loss_direct.item() - loss_adjoint.item()) < 1e-4}")
print()
# Out:
# === Gradient Comparison ===
#   Param  0 | max abs err: 4.56e-03 | max rel err: 6.27e-02 | allclose: False
#   Param  1 | max abs err: 4.36e-03 | max rel err: 7.43e-02 | allclose: False
#   Param  2 | max abs err: 8.25e-03 | max rel err: 8.35e-02 | allclose: False
#   Param  3 | max abs err: 1.03e-03 | max rel err: 1.91e-02 | allclose: False
#
#   Loss direct:  3.675989
#   Loss adjoint: 3.675544
#   Losses match: False

# %%
for nb_steps in [10, 50, 100, 500]:
    
    # Direct
    model.zero_grad()
    step_size_fwd = (t_end - t_0) / nb_steps
    s_0 = torch.cat([y_0.detach(), torch.zeros(batch_size, 1)], dim=1)
    s_end_direct = euler_solver(augmented_dynamics_direct, s_0, t_0, nb_steps, step_size_fwd)[0]
    nll_from_state(s_end_direct).backward()
    grads_direct = [p.grad.clone() for p in model.parameters()]

    # Adjoint
    model.zero_grad()
    params = list(model.parameters())
    s_end_adj = AdjointSolver.apply(model, y_0.detach(), t_0, t_end, nb_steps, euler_solver, *params)
    nll_from_state(s_end_adj).backward()
    grads_adjoint = [p.grad.clone() for p in model.parameters()]

    max_err = max((g_d - g_a).abs().max().item() for g_d, g_a in zip(grads_direct, grads_adjoint))
    print(f"nb_steps={nb_steps:4d} | max abs err: {max_err:.2e}")
# Out:
# nb_steps=  10 | max abs err: 9.48e-02
# nb_steps=  50 | max abs err: 5.22e-02
# nb_steps= 100 | max abs err: 1.08e-02
# nb_steps= 500 | max abs err: 2.89e-02

# %% [markdown]
# ## 4. Model Initialization

# %%
# define vector field net
class MLPVectorField(nn.Module):
    def __init__(self, dim, hidden):
        super().__init__()

        # define 2 hidden layer MLP for vector field
        self.net = nn.Sequential(
            nn.Linear(dim+1, hidden),
            nn.Tanh(),
            nn.Linear(hidden, hidden),
            nn.Tanh(),
            nn.Linear(hidden, hidden),
            nn.Tanh(),
            nn.Linear(hidden, dim)
        )

    def forward(self, y, t):
        # concatenate y and t into 1 input of dim+1
        t_vec = torch.full((y.shape[0], 1), t, device=y.device, dtype=y.dtype)
        inp = torch.cat([y, t_vec], dim=1)

        # calculate forward pass through net
        return self.net(inp)


# define the neural ODE class
class NeuralODE(nn.Module):
    def __init__(self, resolution, dim=2, hidden=16):
        super().__init__()

        # MLP to learn vector field
        self.net = MLPVectorField(dim, hidden)

        # safe how many steps should be made to solve ODE
        self.resolution = resolution

    def forward(self, y_0, t_0, t_end, solver):
        # init forward adjoint
        adjoint_forward = AdjointSolver.apply

        # get parameters
        params = tuple(self.net.parameters())

        # calculate forward pass ODEs
        output = adjoint_forward(self.net, y_0, t_0, t_end, self.resolution, solver, *params)
        y_end = output[:, :-1]
        y_prob = output[:, -1]
        
        return y_end, y_prob

# %% [markdown]
# ## 5. Model Training

# %%
# train step function for Neural ODEs
def make_train_step(model, optimizer, regularization, grad_clipping, ode_solver, dim_data, device):
    # define prior
    prior = torch.distributions.MultivariateNormal(torch.zeros(dim_data, device=device), torch.eye(dim_data, device=device))

    # training function that gets created
    def train_step(y_end, t_0, t_end, verbose=False):
        optimizer.zero_grad()
        model.train()

        # calculate ODE Backward to use MLE on Gauss distr with connection to datapoints
        y_0, delta_prob = model(y_end, t_end, t_0, ode_solver)

        # calculate loss (MLE)
        y_0_prob = prior.log_prob(y_0)
        log_p = y_0_prob - delta_prob # - because we calculate integral from 1 to 0 of -trace which is equal to integral from 0 to 1 of trace
        loss_mle = -log_p.mean()

        # Add FFJORD Refularization to make CNF converge (without it diverges to -inf)
        loss_reg = regularization * (delta_prob ** 2).mean()
        loss = loss_mle + loss_reg

        if verbose:
            print(f"prior term: {y_0_prob.mean().item():.3f}")
            print(f"delta_prob: {delta_prob.mean().item():.3f}")

        # calculate gradient
        loss.backward()

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=grad_clipping)

        # optimization and scheduler
        optimizer.step()

        return loss.item()
    
    return train_step

# %% [markdown]
# ### 5.1 Circle Model Training

# %%
# Circle Training
# training parameters
epochs = 200
lr = 1e-3
t_start = 0
t_end = 1
batch_size = 256
regularization = 0
gradient_clip = 20

# model param
input_dim = 2
dense_dim = 128
resolution = 250

# init model
model_circle = NeuralODE(resolution, input_dim, dense_dim).to(device)
#print(model.state_dict())

# define ODE Solver
solver = rk4_solver

# define an optimizer
optimizer = optim.Adam(model_circle.parameters(), lr=lr, weight_decay=1e-4)

# define lr scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.5)

# show model summary
#summary(model, input_size=(batch_size, input_dim))

# %%
# Turn Datasets into Dataloader (Circle)
circle_data = DataLoader(circle_tensor, batch_size=batch_size)

# create training function
training_step_circle = make_train_step(model_circle, optimizer, regularization, gradient_clip, solver, dim_data=input_dim, device=device)

# Training Loop
train_history_circle = []
for e in range(epochs):
    print(f"\nEpoch: {e+1}")

    batch_loss = []
    for i, point_batch in enumerate(circle_data, 1):
        #print(f"Batch: {i}")
        point_batch = point_batch.to(device)

        # information only some epochs
        verbose=False
        if (((e+1)%10==0 or e+1==1)):
            verbose=True
        
        # perform a train step
        loss_b = training_step_circle(point_batch, t_start, t_end, verbose=verbose)
        batch_loss.append(loss_b)
    
    # calculate loss per epoch
    loss_e = np.array(batch_loss).mean()

    # learning rate scheduler
    scheduler.step(loss_e)
    
    # training statistics
    train_history_circle.append(loss_e)
    print(f"Loss: {loss_e}, , Learning Rate: {optimizer.param_groups[0]['lr']}")
# Out:
# Epoch: 1
# prior term: -2.138
# delta_prob: 0.041
# prior term: -2.250
# delta_prob: -0.249
# prior term: -2.365
# delta_prob: -0.526
# prior term: -2.561
# delta_prob: -0.792
# Loss: 1.9468867480754852, , Learning Rate: 0.001
#
# Epoch: 2
# Loss: 1.7731443643569946, , Learning Rate: 0.001
#
# Epoch: 3
# Loss: 1.7606106102466583, , Learning Rate: 0.001
#
# Epoch: 4
# Loss: 1.7339795529842377, , Learning Rate: 0.001
#
# Epoch: 5
# Loss: 1.7435159981250763, , Learning Rate: 0.001
#
# Epoch: 6
# Loss: 1.7259038388729095, , Learning Rate: 0.001
#
# Epoch: 7
# Loss: 1.7217520773410797, , Learning Rate: 0.001
#
# Epoch: 8
# Loss: 1.7192806899547577, , Learning Rate: 0.001
#
# Epoch: 9
# Loss: 1.7126907706260681, , Learning Rate: 0.001
#
# Epoch: 10
# prior term: -2.733
# delta_prob: -0.995
# prior term: -2.705
# delta_prob: -0.998
# prior term: -2.684
# delta_prob: -1.000
# prior term: -2.731
# delta_prob: -1.010
# Loss: 1.7123856842517853, , Learning Rate: 0.001
#
# Epoch: 11
# Loss: 1.7068705260753632, , Learning Rate: 0.001
#
# Epoch: 12
# Loss: 1.7032849192619324, , Learning Rate: 0.001
#
# Epoch: 13
# Loss: 1.701429396867752, , Learning Rate: 0.001
#
# Epoch: 14
# Loss: 1.698163390159607, , Learning Rate: 0.001
#
# Epoch: 15
# Loss: 1.6942276656627655, , Learning Rate: 0.001
#
# Epoch: 16
# Loss: 1.6910968720912933, , Learning Rate: 0.001
#
# Epoch: 17
# Loss: 1.6881261765956879, , Learning Rate: 0.001
#
# Epoch: 18
# Loss: 1.6840483248233795, , Learning Rate: 0.001
#
# Epoch: 19
# Loss: 1.6802837252616882, , Learning Rate: 0.001
#
# Epoch: 20
# prior term: -2.817
# delta_prob: -1.115
# prior term: -2.791
# delta_prob: -1.121
# prior term: -2.767
# delta_prob: -1.120
# prior term: -2.818
# delta_prob: -1.132
# Loss: 1.6762861907482147, , Learning Rate: 0.001
#
# Epoch: 21
# Loss: 1.6718000173568726, , Learning Rate: 0.001
#
# Epoch: 22
# Loss: 1.6673050224781036, , Learning Rate: 0.001
#
# Epoch: 23
# Loss: 1.6619845032691956, , Learning Rate: 0.001
#
# Epoch: 24
# Loss: 1.6565647423267365, , Learning Rate: 0.001
#
# Epoch: 25
# Loss: 1.650814712047577, , Learning Rate: 0.001
#
# Epoch: 26
# Loss: 1.644087314605713, , Learning Rate: 0.001
#
# Epoch: 27
# Loss: 1.6374956965446472, , Learning Rate: 0.001
#
# Epoch: 28
# Loss: 1.6303249895572662, , Learning Rate: 0.001
#
# Epoch: 29
# Loss: 1.6223371624946594, , Learning Rate: 0.001
#
# Epoch: 30
# prior term: -2.846
# delta_prob: -1.205
# prior term: -2.793
# delta_prob: -1.190
# prior term: -2.769
# delta_prob: -1.182
# prior term: -2.841
# delta_prob: -1.215
# Loss: 1.6142738461494446, , Learning Rate: 0.001
#
# Epoch: 31
# Loss: 1.6056552529335022, , Learning Rate: 0.001
#
# Epoch: 32
# Loss: 1.5972733199596405, , Learning Rate: 0.001
#
# Epoch: 33
# Loss: 1.5885053873062134, , Learning Rate: 0.001
#
# Epoch: 34
# Loss: 1.580552577972412, , Learning Rate: 0.001
#
# Epoch: 35
# Loss: 1.5712612867355347, , Learning Rate: 0.001
#
# Epoch: 36
# Loss: 1.5644232332706451, , Learning Rate: 0.001
#
# Epoch: 37
# Loss: 1.5561171770095825, , Learning Rate: 0.001
#
# Epoch: 38
# Loss: 1.5489057898521423, , Learning Rate: 0.001
#
# Epoch: 39
# Loss: 1.5435529053211212, , Learning Rate: 0.001
#
# Epoch: 40
# prior term: -2.846
# delta_prob: -1.292
# prior term: -2.742
# delta_prob: -1.218
# prior term: -2.752
# delta_prob: -1.236
# prior term: -2.869
# delta_prob: -1.316
# Loss: 1.536716789007187, , Learning Rate: 0.001
#
# Epoch: 41
# Loss: 1.53096604347229, , Learning Rate: 0.001
#
# Epoch: 42
# Loss: 1.5262367725372314, , Learning Rate: 0.001
#
# Epoch: 43
# Loss: 1.520010232925415, , Learning Rate: 0.001
#
# Epoch: 44
# Loss: 1.51581409573555, , Learning Rate: 0.001
#
# Epoch: 45
# Loss: 1.512389212846756, , Learning Rate: 0.001
#
# Epoch: 46
# Loss: 1.5062729120254517, , Learning Rate: 0.001
#
# Epoch: 47
# Loss: 1.5029734075069427, , Learning Rate: 0.001
#
# Epoch: 48
# Loss: 1.4981224238872528, , Learning Rate: 0.001
#
# Epoch: 49
# Loss: 1.4954688251018524, , Learning Rate: 0.001
#
# Epoch: 50
# prior term: -2.817
# delta_prob: -1.316
# prior term: -2.755
# delta_prob: -1.274
# prior term: -2.738
# delta_prob: -1.259
# prior term: -2.828
# delta_prob: -1.321
# Loss: 1.4918517470359802, , Learning Rate: 0.001
#
# Epoch: 51
# Loss: 1.487849235534668, , Learning Rate: 0.001
#
# Epoch: 52
# Loss: 1.4852621257305145, , Learning Rate: 0.001
#
# Epoch: 53
# Loss: 1.482073426246643, , Learning Rate: 0.001
#
# Epoch: 54
# Loss: 1.4825588166713715, , Learning Rate: 0.001
#
# Epoch: 55
# Loss: 1.4822617769241333, , Learning Rate: 0.001
#
# Epoch: 56
# Loss: 1.4816233813762665, , Learning Rate: 0.001
#
# Epoch: 57
# Loss: 1.4822747111320496, , Learning Rate: 0.001
#
# Epoch: 58
# Loss: 1.4772341549396515, , Learning Rate: 0.001
#
# Epoch: 59
# Loss: 1.4705966114997864, , Learning Rate: 0.001
#
# Epoch: 60
# prior term: -2.845
# delta_prob: -1.381
# prior term: -2.652
# delta_prob: -1.180
# prior term: -2.630
# delta_prob: -1.182
# prior term: -2.945
# delta_prob: -1.455
# Loss: 1.4681150615215302, , Learning Rate: 0.001
#
# Epoch: 61
# Loss: 1.4597382247447968, , Learning Rate: 0.001
#
# Epoch: 62
# Loss: 1.4582322835922241, , Learning Rate: 0.001
#
# Epoch: 63
# Loss: 1.4584409892559052, , Learning Rate: 0.001
#
# Epoch: 64
# Loss: 1.4601526260375977, , Learning Rate: 0.001
#
# Epoch: 65
# Loss: 1.458416759967804, , Learning Rate: 0.001
#
# Epoch: 66
# Loss: 1.449268400669098, , Learning Rate: 0.001
#
# Epoch: 67
# Loss: 1.4423493146896362, , Learning Rate: 0.001
#
# Epoch: 68
# Loss: 1.4385189414024353, , Learning Rate: 0.001
#
# Epoch: 69
# Loss: 1.4365915656089783, , Learning Rate: 0.001
#
# Epoch: 70
# prior term: -2.881
# delta_prob: -1.454
# prior term: -2.804
# delta_prob: -1.370
# prior term: -2.638
# delta_prob: -1.225
# prior term: -2.800
# delta_prob: -1.345
# Loss: 1.4321888387203217, , Learning Rate: 0.001
#
# Epoch: 71
# Loss: 1.4278259873390198, , Learning Rate: 0.001
#
# Epoch: 72
# Loss: 1.4246363043785095, , Learning Rate: 0.001
#
# Epoch: 73
# Loss: 1.423163741827011, , Learning Rate: 0.001
#
# Epoch: 74
# Loss: 1.420332431793213, , Learning Rate: 0.001
#
# Epoch: 75
# Loss: 1.4174719750881195, , Learning Rate: 0.001
#
# Epoch: 76
# Loss: 1.4140090346336365, , Learning Rate: 0.001
#
# Epoch: 77
# Loss: 1.417410135269165, , Learning Rate: 0.001
#
# Epoch: 78
# Loss: 1.4222660958766937, , Learning Rate: 0.001
#
# Epoch: 79
# Loss: 1.4676032662391663, , Learning Rate: 0.001
#
# Epoch: 80
# prior term: -2.779
# delta_prob: -1.176
# prior term: -2.623
# delta_prob: -1.072
# prior term: -2.609
# delta_prob: -1.137
# prior term: -3.178
# delta_prob: -1.524
# Loss: 1.5701899528503418, , Learning Rate: 0.0005
#
# Epoch: 81
# Loss: 1.4096119701862335, , Learning Rate: 0.0005
#
# Epoch: 82
# Loss: 1.4073472917079926, , Learning Rate: 0.0005
#
# Epoch: 83
# Loss: 1.3955802619457245, , Learning Rate: 0.0005
#
# Epoch: 84
# Loss: 1.3870919048786163, , Learning Rate: 0.0005
#
# Epoch: 85
# Loss: 1.3858190476894379, , Learning Rate: 0.0005
#
# Epoch: 86
# Loss: 1.3816732466220856, , Learning Rate: 0.0005
#
# Epoch: 87
# Loss: 1.382680594921112, , Learning Rate: 0.0005
#
# Epoch: 88
# Loss: 1.372803121805191, , Learning Rate: 0.0005
#
# Epoch: 89
# Loss: 1.372611254453659, , Learning Rate: 0.0005
#
# Epoch: 90
# prior term: -2.783
# delta_prob: -1.443
# prior term: -2.817
# delta_prob: -1.433
# prior term: -2.747
# delta_prob: -1.384
# prior term: -2.816
# delta_prob: -1.422
# Loss: 1.3701203167438507, , Learning Rate: 0.0005
#
# Epoch: 91
# Loss: 1.3702756762504578, , Learning Rate: 0.0005
#
# Epoch: 92
# Loss: 1.3669903874397278, , Learning Rate: 0.0005
#
# Epoch: 93
# Loss: 1.3623197674751282, , Learning Rate: 0.0005
#
# Epoch: 94
# Loss: 1.3626205027103424, , Learning Rate: 0.0005
#
# Epoch: 95
# Loss: 1.3586508333683014, , Learning Rate: 0.0005
#
# Epoch: 96
# Loss: 1.3601020872592926, , Learning Rate: 0.0005
#
# Epoch: 97
# Loss: 1.3599003553390503, , Learning Rate: 0.0005
#
# Epoch: 98
# Loss: 1.3592661619186401, , Learning Rate: 0.0005
#
# Epoch: 99
# Loss: 1.3607249557971954, , Learning Rate: 0.00025
#
# Epoch: 100
# prior term: -2.752
# delta_prob: -1.429
# prior term: -2.763
# delta_prob: -1.403
# prior term: -2.740
# delta_prob: -1.386
# prior term: -2.834
# delta_prob: -1.455
# Loss: 1.3539197444915771, , Learning Rate: 0.00025
#
# Epoch: 101
# Loss: 1.346396565437317, , Learning Rate: 0.00025
#
# Epoch: 102
# Loss: 1.3449013531208038, , Learning Rate: 0.00025
#
# Epoch: 103
# Loss: 1.3431090116500854, , Learning Rate: 0.00025
#
# Epoch: 104
# Loss: 1.342179298400879, , Learning Rate: 0.00025
#
# Epoch: 105
# Loss: 1.3406808972358704, , Learning Rate: 0.00025
#
# Epoch: 106
# Loss: 1.3406729698181152, , Learning Rate: 0.00025
#
# Epoch: 107
# Loss: 1.3349319398403168, , Learning Rate: 0.00025
#
# Epoch: 108
# Loss: 1.3357575237751007, , Learning Rate: 0.00025
#
# Epoch: 109
# Loss: 1.3341988325119019, , Learning Rate: 0.00025
#
# Epoch: 110
# prior term: -2.786
# delta_prob: -1.501
# prior term: -2.786
# delta_prob: -1.438
# prior term: -2.702
# delta_prob: -1.364
# prior term: -2.794
# delta_prob: -1.436
# Loss: 1.3324121832847595, , Learning Rate: 0.00025
#
# Epoch: 111
# Loss: 1.3321369290351868, , Learning Rate: 0.00025
#
# Epoch: 112
# Loss: 1.3313751220703125, , Learning Rate: 0.00025
#
# Epoch: 113
# Loss: 1.32935830950737, , Learning Rate: 0.00025
#
# Epoch: 114
# Loss: 1.3292017579078674, , Learning Rate: 0.00025
#
# Epoch: 115
# Loss: 1.3279666900634766, , Learning Rate: 0.00025
#
# Epoch: 116
# Loss: 1.326562613248825, , Learning Rate: 0.00025
#
# Epoch: 117
# Loss: 1.3248029053211212, , Learning Rate: 0.00025
#
# Epoch: 118
# Loss: 1.324272781610489, , Learning Rate: 0.00025
#
# Epoch: 119
# Loss: 1.3219656348228455, , Learning Rate: 0.00025
#
# Epoch: 120
# prior term: -2.768
# delta_prob: -1.496
# prior term: -2.775
# delta_prob: -1.439
# prior term: -2.706
# delta_prob: -1.374
# prior term: -2.797
# delta_prob: -1.449
# Loss: 1.3222773671150208, , Learning Rate: 0.00025
#
# Epoch: 121
# Loss: 1.3215625882148743, , Learning Rate: 0.00025
#
# Epoch: 122
# Loss: 1.321006953716278, , Learning Rate: 0.00025
#
# Epoch: 123
# Loss: 1.3174227178096771, , Learning Rate: 0.00025
#
# Epoch: 124
# Loss: 1.3156509101390839, , Learning Rate: 0.00025
#
# Epoch: 125
# Loss: 1.3158253133296967, , Learning Rate: 0.00025
#
# Epoch: 126
# Loss: 1.3159711360931396, , Learning Rate: 0.00025
#
# Epoch: 127
# Loss: 1.314035177230835, , Learning Rate: 0.00025
#
# Epoch: 128
# Loss: 1.311141163110733, , Learning Rate: 0.00025
#
# Epoch: 129
# Loss: 1.3112407326698303, , Learning Rate: 0.00025
#
# Epoch: 130
# prior term: -2.764
# delta_prob: -1.505
# prior term: -2.780
# delta_prob: -1.456
# prior term: -2.711
# delta_prob: -1.386
# prior term: -2.789
# delta_prob: -1.459
# Loss: 1.3095716834068298, , Learning Rate: 0.00025
#
# Epoch: 131
# Loss: 1.308459758758545, , Learning Rate: 0.00025
#
# Epoch: 132
# Loss: 1.3061016499996185, , Learning Rate: 0.00025
#
# Epoch: 133
# Loss: 1.3070823848247528, , Learning Rate: 0.00025
#
# Epoch: 134
# Loss: 1.3036435842514038, , Learning Rate: 0.00025
#
# Epoch: 135
# Loss: 1.3037050068378448, , Learning Rate: 0.00025
#
# Epoch: 136
# Loss: 1.30266734957695, , Learning Rate: 0.00025
#
# Epoch: 137
# Loss: 1.3002640306949615, , Learning Rate: 0.00025
#
# Epoch: 138
# Loss: 1.2986292839050293, , Learning Rate: 0.00025
#
# Epoch: 139
# Loss: 1.2969436943531036, , Learning Rate: 0.00025
#
# Epoch: 140
# prior term: -2.763
# delta_prob: -1.518
# prior term: -2.781
# delta_prob: -1.476
# prior term: -2.710
# delta_prob: -1.396
# prior term: -2.786
# delta_prob: -1.466
# Loss: 1.2960296869277954, , Learning Rate: 0.00025
#
# Epoch: 141
# Loss: 1.2948167026042938, , Learning Rate: 0.00025
#
# Epoch: 142
# Loss: 1.2939571142196655, , Learning Rate: 0.00025
#
# Epoch: 143
# Loss: 1.2925552725791931, , Learning Rate: 0.00025
#
# Epoch: 144
# Loss: 1.2901910543441772, , Learning Rate: 0.00025
#
# Epoch: 145
# Loss: 1.2881709039211273, , Learning Rate: 0.00025
#
# Epoch: 146
# Loss: 1.28968745470047, , Learning Rate: 0.00025
#
# Epoch: 147
# Loss: 1.2856695055961609, , Learning Rate: 0.00025
#
# Epoch: 148
# Loss: 1.2854855954647064, , Learning Rate: 0.00025
#
# Epoch: 149
# Loss: 1.284115195274353, , Learning Rate: 0.00025
#
# Epoch: 150
# prior term: -2.761
# delta_prob: -1.531
# prior term: -2.787
# delta_prob: -1.497
# prior term: -2.715
# delta_prob: -1.408
# prior term: -2.782
# delta_prob: -1.480
# Loss: 1.2821928560733795, , Learning Rate: 0.00025
#
# Epoch: 151
# Loss: 1.2803130149841309, , Learning Rate: 0.00025
#
# Epoch: 152
# Loss: 1.278562068939209, , Learning Rate: 0.00025
#
# Epoch: 153
# Loss: 1.2763001024723053, , Learning Rate: 0.00025
#
# Epoch: 154
# Loss: 1.2756109833717346, , Learning Rate: 0.00025
#
# Epoch: 155
# Loss: 1.2714844346046448, , Learning Rate: 0.00025
#
# Epoch: 156
# Loss: 1.273201048374176, , Learning Rate: 0.00025
#
# Epoch: 157
# Loss: 1.27071014046669, , Learning Rate: 0.00025
#
# Epoch: 158
# Loss: 1.2702927589416504, , Learning Rate: 0.00025
#
# Epoch: 159
# Loss: 1.2690823674201965, , Learning Rate: 0.00025
#
# Epoch: 160
# prior term: -2.755
# delta_prob: -1.543
# prior term: -2.786
# delta_prob: -1.513
# prior term: -2.713
# delta_prob: -1.418
# prior term: -2.781
# delta_prob: -1.493
# Loss: 1.266991376876831, , Learning Rate: 0.00025
#
# Epoch: 161
# Loss: 1.2647669315338135, , Learning Rate: 0.00025
#
# Epoch: 162
# Loss: 1.2624130249023438, , Learning Rate: 0.00025
#
# Epoch: 163
# Loss: 1.262088119983673, , Learning Rate: 0.00025
#
# Epoch: 164
# Loss: 1.2600391805171967, , Learning Rate: 0.00025
#
# Epoch: 165
# Loss: 1.2600343525409698, , Learning Rate: 0.00025
#
# Epoch: 166
# Loss: 1.258425921201706, , Learning Rate: 0.00025
#
# Epoch: 167
# Loss: 1.2560379803180695, , Learning Rate: 0.00025
#
# Epoch: 168
# Loss: 1.2535541951656342, , Learning Rate: 0.00025
#
# Epoch: 169
# Loss: 1.253890484571457, , Learning Rate: 0.00025
#
# Epoch: 170
# prior term: -2.753
# delta_prob: -1.561
# prior term: -2.786
# delta_prob: -1.533
# prior term: -2.714
# delta_prob: -1.430
# prior term: -2.781
# delta_prob: -1.505
# Loss: 1.2511782348155975, , Learning Rate: 0.00025
#
# Epoch: 171
# Loss: 1.2497710883617401, , Learning Rate: 0.00025
#
# Epoch: 172
# Loss: 1.2468304932117462, , Learning Rate: 0.00025
#
# Epoch: 173
# Loss: 1.2466118037700653, , Learning Rate: 0.00025
#
# Epoch: 174
# Loss: 1.2450932562351227, , Learning Rate: 0.00025
#
# Epoch: 175
# Loss: 1.2428063452243805, , Learning Rate: 0.00025
#
# Epoch: 176
# Loss: 1.242771714925766, , Learning Rate: 0.00025
#
# Epoch: 177
# Loss: 1.2396769225597382, , Learning Rate: 0.00025
#
# Epoch: 178
# Loss: 1.2387636601924896, , Learning Rate: 0.00025
#
# Epoch: 179
# Loss: 1.2370761632919312, , Learning Rate: 0.00025
#
# Epoch: 180
# prior term: -2.754
# delta_prob: -1.575
# prior term: -2.785
# delta_prob: -1.547
# prior term: -2.711
# delta_prob: -1.435
# prior term: -2.777
# delta_prob: -1.523
# Loss: 1.2366788983345032, , Learning Rate: 0.00025
#
# Epoch: 181
# Loss: 1.2316527366638184, , Learning Rate: 0.00025
#
# Epoch: 182
# Loss: 1.2338479161262512, , Learning Rate: 0.00025
#
# Epoch: 183
# Loss: 1.231707513332367, , Learning Rate: 0.00025
#
# Epoch: 184
# Loss: 1.2284909784793854, , Learning Rate: 0.00025
#
# Epoch: 185
# Loss: 1.228570431470871, , Learning Rate: 0.00025
#
# Epoch: 186
# Loss: 1.225334882736206, , Learning Rate: 0.00025
#
# Epoch: 187
# Loss: 1.225101262331009, , Learning Rate: 0.00025
#
# Epoch: 188
# Loss: 1.2203381657600403, , Learning Rate: 0.00025
#
# Epoch: 189
# Loss: 1.219483107328415, , Learning Rate: 0.00025
#
# Epoch: 190
# prior term: -2.754
# delta_prob: -1.593
# prior term: -2.788
# delta_prob: -1.566
# prior term: -2.707
# delta_prob: -1.448
# prior term: -2.776
# delta_prob: -1.536
# Loss: 1.2204331755638123, , Learning Rate: 0.00025
#
# Epoch: 191
# Loss: 1.2184113562107086, , Learning Rate: 0.00025
#
# Epoch: 192
# Loss: 1.2148340344429016, , Learning Rate: 0.00025
#
# Epoch: 193
# Loss: 1.2136958539485931, , Learning Rate: 0.00025
#
# Epoch: 194
# Loss: 1.213028907775879, , Learning Rate: 0.00025
#
# Epoch: 195
# Loss: 1.212301641702652, , Learning Rate: 0.00025
#
# Epoch: 196
# Loss: 1.2108755111694336, , Learning Rate: 0.00025
#
# Epoch: 197
# Loss: 1.2076134085655212, , Learning Rate: 0.00025
#
# Epoch: 198
# Loss: 1.2063285112380981, , Learning Rate: 0.00025
#
# Epoch: 199
# Loss: 1.205262005329132, , Learning Rate: 0.00025
#
# Epoch: 200
# prior term: -2.745
# delta_prob: -1.596
# prior term: -2.785
# delta_prob: -1.581
# prior term: -2.715
# delta_prob: -1.467
# prior term: -2.786
# delta_prob: -1.573
# Loss: 1.2032825350761414, , Learning Rate: 0.00025

# %% [markdown]
# ### 5.2 Moon Model Training

# %%
# Moon Training
# training parameters
epochs = 150
lr = 1e-3
t_start = 0
t_end = 1
batch_size = 256
regularization = 1e-6
gradient_clip = 15

# model param
input_dim = 2
dense_dim = 128
resolution = 250

# init model
model_moon = NeuralODE(resolution, input_dim, dense_dim).to(device)
#print(model.state_dict())

# define ODE Solver
solver = rk4_solver

# define an optimizer
optimizer = optim.Adam(model_moon.parameters(), lr=lr, weight_decay=1e-4)

# define lr scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=3, factor=0.5)

# show model summary
#summary(model, input_size=(batch_size, input_dim))

# %%
# Turn Datasets into Dataloader (Moon)
moon_data = DataLoader(moon_tensor, batch_size=batch_size)

# create training function
training_step_moon = make_train_step(model_moon, optimizer, regularization, gradient_clip, solver, dim_data=input_dim, device=device)

# Training Loop
train_history_moon = []
for e in range(epochs):
    print(f"\nEpoch: {e+1}")

    batch_loss = []
    for i, point_batch in enumerate(moon_data, 1):
        #print(f"Batch: {i}")
        point_batch = point_batch.to(device)

        # information only some epochs
        verbose=False
        if (((e+1)%10==0 or e+1==1)):
            verbose=True
        
        # perform a train step
        loss_b = training_step_moon(point_batch, t_start, t_end, verbose=verbose)
        batch_loss.append(loss_b)
    
    # calculate loss per epoch
    loss_e = np.array(batch_loss).mean()

    # learning rate scheduler
    scheduler.step(loss_e)
    
    # training statistics
    train_history_moon.append(loss_e)
    print(f"Loss: {loss_e}, , Learning Rate: {optimizer.param_groups[0]['lr']}")
# Out:
# Epoch: 1
# prior term: -2.334
# delta_prob: 0.144
# prior term: -2.338
# delta_prob: -0.034
# prior term: -2.424
# delta_prob: -0.230
# prior term: -2.530
# delta_prob: -0.396
# Loss: 2.2774174213409424, , Learning Rate: 0.001
#
# Epoch: 2
# Loss: 1.9821282923221588, , Learning Rate: 0.001
#
# Epoch: 3
# Loss: 1.9941528737545013, , Learning Rate: 0.001
#
# Epoch: 4
# Loss: 1.9442704021930695, , Learning Rate: 0.001
#
# Epoch: 5
# Loss: 1.9516047239303589, , Learning Rate: 0.001
#
# Epoch: 6
# Loss: 1.9222024381160736, , Learning Rate: 0.001
#
# Epoch: 7
# Loss: 1.9130038619041443, , Learning Rate: 0.001
#
# Epoch: 8
# Loss: 1.8973620533943176, , Learning Rate: 0.001
#
# Epoch: 9
# Loss: 1.8783124685287476, , Learning Rate: 0.001
#
# Epoch: 10
# prior term: -2.715
# delta_prob: -0.848
# prior term: -2.703
# delta_prob: -0.853
# prior term: -2.711
# delta_prob: -0.856
# prior term: -2.733
# delta_prob: -0.869
# Loss: 1.8589691817760468, , Learning Rate: 0.001
#
# Epoch: 11
# Loss: 1.8346957564353943, , Learning Rate: 0.001
#
# Epoch: 12
# Loss: 1.800989806652069, , Learning Rate: 0.001
#
# Epoch: 13
# Loss: 1.7582268416881561, , Learning Rate: 0.001
#
# Epoch: 14
# Loss: 1.7116836607456207, , Learning Rate: 0.001
#
# Epoch: 15
# Loss: 1.6642352044582367, , Learning Rate: 0.001
#
# Epoch: 16
# Loss: 1.6302768886089325, , Learning Rate: 0.001
#
# Epoch: 17
# Loss: 1.6066206991672516, , Learning Rate: 0.001
#
# Epoch: 18
# Loss: 1.5726039111614227, , Learning Rate: 0.001
#
# Epoch: 19
# Loss: 1.5332160294055939, , Learning Rate: 0.001
#
# Epoch: 20
# prior term: -2.665
# delta_prob: -1.110
# prior term: -2.664
# delta_prob: -1.219
# prior term: -2.891
# delta_prob: -1.422
# prior term: -2.977
# delta_prob: -1.507
# Loss: 1.4847187101840973, , Learning Rate: 0.001
#
# Epoch: 21
# Loss: 1.421858698129654, , Learning Rate: 0.001
#
# Epoch: 22
# Loss: 1.3484584987163544, , Learning Rate: 0.001
#
# Epoch: 23
# Loss: 1.2845368087291718, , Learning Rate: 0.001
#
# Epoch: 24
# Loss: 1.247810810804367, , Learning Rate: 0.001
#
# Epoch: 25
# Loss: 1.2782147824764252, , Learning Rate: 0.001
#
# Epoch: 26
# Loss: 1.1419316232204437, , Learning Rate: 0.001
#
# Epoch: 27
# Loss: 1.0229822397232056, , Learning Rate: 0.001
#
# Epoch: 28
# Loss: 1.010990485548973, , Learning Rate: 0.001
#
# Epoch: 29
# Loss: 1.0105773508548737, , Learning Rate: 0.001
#
# Epoch: 30
# prior term: -3.371
# delta_prob: -2.267
# prior term: -3.370
# delta_prob: -2.345
# prior term: -2.788
# delta_prob: -1.944
# prior term: -2.822
# delta_prob: -1.853
# Loss: 0.9857937544584274, , Learning Rate: 0.001
#
# Epoch: 31
# Loss: 0.876800000667572, , Learning Rate: 0.001
#
# Epoch: 32
# Loss: 0.8584940582513809, , Learning Rate: 0.001
#
# Epoch: 33
# Loss: 0.9012213200330734, , Learning Rate: 0.001
#
# Epoch: 34
# Loss: 0.7479754090309143, , Learning Rate: 0.001
#
# Epoch: 35
# Loss: 0.834786519408226, , Learning Rate: 0.001
#
# Epoch: 36
# Loss: 0.96452996134758, , Learning Rate: 0.001
#
# Epoch: 37
# Loss: 0.832849532365799, , Learning Rate: 0.001
#
# Epoch: 38
# Loss: 0.6395683884620667, , Learning Rate: 0.001
#
# Epoch: 39
# Loss: 0.8005878329277039, , Learning Rate: 0.001
#
# Epoch: 40
# prior term: -2.844
# delta_prob: -1.903
# prior term: -2.539
# delta_prob: -1.758
# prior term: -2.904
# delta_prob: -2.091
# prior term: -2.801
# delta_prob: -2.264
# Loss: 0.7682586014270782, , Learning Rate: 0.001
#
# Epoch: 41
# Loss: 0.9877395033836365, , Learning Rate: 0.001
#
# Epoch: 42
# Loss: 0.997987300157547, , Learning Rate: 0.0005
#
# Epoch: 43
# Loss: 0.768726259469986, , Learning Rate: 0.0005
#
# Epoch: 44
# Loss: 0.6254211962223053, , Learning Rate: 0.0005
#
# Epoch: 45
# Loss: 0.6424514651298523, , Learning Rate: 0.0005
#
# Epoch: 46
# Loss: 0.5692710354924202, , Learning Rate: 0.0005
#
# Epoch: 47
# Loss: 0.5301223248243332, , Learning Rate: 0.0005
#
# Epoch: 48
# Loss: 0.5021887198090553, , Learning Rate: 0.0005
#
# Epoch: 49
# Loss: 0.4886569008231163, , Learning Rate: 0.0005
#
# Epoch: 50
# prior term: -2.941
# delta_prob: -2.438
# prior term: -2.950
# delta_prob: -2.378
# prior term: -2.851
# delta_prob: -2.307
# prior term: -2.753
# delta_prob: -2.307
# Loss: 0.5159639939665794, , Learning Rate: 0.0005
#
# Epoch: 51
# Loss: 0.5234069973230362, , Learning Rate: 0.0005
#
# Epoch: 52
# Loss: 0.4355267882347107, , Learning Rate: 0.0005
#
# Epoch: 53
# Loss: 0.448920302093029, , Learning Rate: 0.0005
#
# Epoch: 54
# Loss: 0.483209989964962, , Learning Rate: 0.0005
#
# Epoch: 55
# Loss: 0.4953949600458145, , Learning Rate: 0.0005
#
# Epoch: 56
# Loss: 0.40680790692567825, , Learning Rate: 0.0005
#
# Epoch: 57
# Loss: 0.43087059259414673, , Learning Rate: 0.0005
#
# Epoch: 58
# Loss: 0.4656999781727791, , Learning Rate: 0.0005
#
# Epoch: 59
# Loss: 0.4487954005599022, , Learning Rate: 0.0005
#
# Epoch: 60
# prior term: -3.028
# delta_prob: -2.579
# prior term: -2.982
# delta_prob: -2.601
# prior term: -2.857
# delta_prob: -2.452
# prior term: -2.787
# delta_prob: -2.369
# Loss: 0.4129970222711563, , Learning Rate: 0.00025
#
# Epoch: 61
# Loss: 0.3714785575866699, , Learning Rate: 0.00025
#
# Epoch: 62
# Loss: 0.3749127835035324, , Learning Rate: 0.00025
#
# Epoch: 63
# Loss: 0.35853100568056107, , Learning Rate: 0.00025
#
# Epoch: 64
# Loss: 0.3623328357934952, , Learning Rate: 0.00025
#
# Epoch: 65
# Loss: 0.35006362199783325, , Learning Rate: 0.00025
#
# Epoch: 66
# Loss: 0.34626614302396774, , Learning Rate: 0.00025
#
# Epoch: 67
# Loss: 0.3379035033285618, , Learning Rate: 0.00025
#
# Epoch: 68
# Loss: 0.3220585808157921, , Learning Rate: 0.00025
#
# Epoch: 69
# Loss: 0.3239758685231209, , Learning Rate: 0.00025
#
# Epoch: 70
# prior term: -2.901
# delta_prob: -2.571
# prior term: -2.853
# delta_prob: -2.527
# prior term: -2.857
# delta_prob: -2.501
# prior term: -2.816
# delta_prob: -2.582
# Loss: 0.31183113157749176, , Learning Rate: 0.00025
#
# Epoch: 71
# Loss: 0.3196936547756195, , Learning Rate: 0.00025
#
# Epoch: 72
# Loss: 0.29839400202035904, , Learning Rate: 0.00025
#
# Epoch: 73
# Loss: 0.30656901001930237, , Learning Rate: 0.00025
#
# Epoch: 74
# Loss: 0.29219330474734306, , Learning Rate: 0.00025
#
# Epoch: 75
# Loss: 0.2914813160896301, , Learning Rate: 0.00025
#
# Epoch: 76
# Loss: 0.2834899239242077, , Learning Rate: 0.00025
#
# Epoch: 77
# Loss: 0.2800355814397335, , Learning Rate: 0.00025
#
# Epoch: 78
# Loss: 0.2767392098903656, , Learning Rate: 0.00025
#
# Epoch: 79
# Loss: 0.2687249258160591, , Learning Rate: 0.00025
#
# Epoch: 80
# prior term: -2.996
# delta_prob: -2.690
# prior term: -2.955
# delta_prob: -2.677
# prior term: -2.896
# delta_prob: -2.588
# prior term: -2.799
# delta_prob: -2.604
# Loss: 0.27192511409521103, , Learning Rate: 0.00025
#
# Epoch: 81
# Loss: 0.26127713918685913, , Learning Rate: 0.00025
#
# Epoch: 82
# Loss: 0.2610096000134945, , Learning Rate: 0.00025
#
# Epoch: 83
# Loss: 0.25542622059583664, , Learning Rate: 0.00025
#
# Epoch: 84
# Loss: 0.2507043518126011, , Learning Rate: 0.00025
#
# Epoch: 85
# Loss: 0.25036024302244186, , Learning Rate: 0.00025
#
# Epoch: 86
# Loss: 0.25141916796565056, , Learning Rate: 0.00025
#
# Epoch: 87
# Loss: 0.24226676672697067, , Learning Rate: 0.00025
#
# Epoch: 88
# Loss: 0.24772077426314354, , Learning Rate: 0.00025
#
# Epoch: 89
# Loss: 0.23324985802173615, , Learning Rate: 0.00025
#
# Epoch: 90
# prior term: -2.972
# delta_prob: -2.709
# prior term: -2.944
# delta_prob: -2.696
# prior term: -2.899
# delta_prob: -2.624
# prior term: -2.816
# delta_prob: -2.656
# Loss: 0.23654231801629066, , Learning Rate: 0.00025
#
# Epoch: 91
# Loss: 0.2307027094066143, , Learning Rate: 0.00025
#
# Epoch: 92
# Loss: 0.22865388169884682, , Learning Rate: 0.00025
#
# Epoch: 93
# Loss: 0.2244798243045807, , Learning Rate: 0.00025
#
# Epoch: 94
# Loss: 0.2214998845010996, , Learning Rate: 0.00025
#
# Epoch: 95
# Loss: 0.21553794294595718, , Learning Rate: 0.00025
#
# Epoch: 96
# Loss: 0.21703547053039074, , Learning Rate: 0.00025
#
# Epoch: 97
# Loss: 0.21278811804950237, , Learning Rate: 0.00025
#
# Epoch: 98
# Loss: 0.21027889102697372, , Learning Rate: 0.00025
#
# Epoch: 99
# Loss: 0.21200683154165745, , Learning Rate: 0.00025
#
# Epoch: 100
# prior term: -2.997
# delta_prob: -2.763
# prior term: -2.969
# delta_prob: -2.745
# prior term: -2.915
# delta_prob: -2.667
# prior term: -2.832
# delta_prob: -2.723
# Loss: 0.20395957678556442, , Learning Rate: 0.00025
#
# Epoch: 101
# Loss: 0.20690706185996532, , Learning Rate: 0.00025
#
# Epoch: 102
# Loss: 0.20329763926565647, , Learning Rate: 0.00025
#
# Epoch: 103
# Loss: 0.1896238997578621, , Learning Rate: 0.00025
#
# Epoch: 104
# Loss: 0.1990213505923748, , Learning Rate: 0.00025
#
# Epoch: 105
# Loss: 0.18598486855626106, , Learning Rate: 0.00025
#
# Epoch: 106
# Loss: 0.1853173729032278, , Learning Rate: 0.00025
#
# Epoch: 107
# Loss: 0.18979001604020596, , Learning Rate: 0.00025
#
# Epoch: 108
# Loss: 0.17858725786209106, , Learning Rate: 0.00025
#
# Epoch: 109
# Loss: 0.1812462005764246, , Learning Rate: 0.00025
#
# Epoch: 110
# prior term: -2.970
# delta_prob: -2.743
# prior term: -2.973
# delta_prob: -2.782
# prior term: -2.944
# delta_prob: -2.722
# prior term: -2.873
# delta_prob: -2.773
# Loss: 0.18515782430768013, , Learning Rate: 0.00025
#
# Epoch: 111
# Loss: 0.16972190141677856, , Learning Rate: 0.00025
#
# Epoch: 112
# Loss: 0.1753247193992138, , Learning Rate: 0.00025
#
# Epoch: 113
# Loss: 0.1732592787593603, , Learning Rate: 0.00025
#
# Epoch: 114
# Loss: 0.16040258202701807, , Learning Rate: 0.00025
#
# Epoch: 115
# Loss: 0.16829130612313747, , Learning Rate: 0.00025
#
# Epoch: 116
# Loss: 0.16057814471423626, , Learning Rate: 0.00025
#
# Epoch: 117
# Loss: 0.16709348745644093, , Learning Rate: 0.00025
#
# Epoch: 118
# Loss: 0.1566797625273466, , Learning Rate: 0.00025
#
# Epoch: 119
# Loss: 0.15752469561994076, , Learning Rate: 0.00025
#
# Epoch: 120
# prior term: -2.938
# delta_prob: -2.734
# prior term: -2.935
# delta_prob: -2.764
# prior term: -2.929
# delta_prob: -2.728
# prior term: -2.879
# delta_prob: -2.803
# Loss: 0.16284138336777687, , Learning Rate: 0.00025
#
# Epoch: 121
# Loss: 0.14910085313022137, , Learning Rate: 0.00025
#
# Epoch: 122
# Loss: 0.15032934211194515, , Learning Rate: 0.00025
#
# Epoch: 123
# Loss: 0.1498747244477272, , Learning Rate: 0.00025
#
# Epoch: 124
# Loss: 0.15106944367289543, , Learning Rate: 0.00025
#
# Epoch: 125
# Loss: 0.15324192494153976, , Learning Rate: 0.000125
#
# Epoch: 126
# Loss: 0.13201674167066813, , Learning Rate: 0.000125
#
# Epoch: 127
# Loss: 0.13107768818736076, , Learning Rate: 0.000125
#
# Epoch: 128
# Loss: 0.13513497542589903, , Learning Rate: 0.000125
#
# Epoch: 129
# Loss: 0.1296982392668724, , Learning Rate: 0.000125
#
# Epoch: 130
# prior term: -2.921
# delta_prob: -2.775
# prior term: -2.911
# delta_prob: -2.761
# prior term: -2.923
# delta_prob: -2.749
# prior term: -2.883
# delta_prob: -2.851
# Loss: 0.12537350691854954, , Learning Rate: 0.000125
#
# Epoch: 131
# Loss: 0.12687767948955297, , Learning Rate: 0.000125
#
# Epoch: 132
# Loss: 0.12936392985284328, , Learning Rate: 0.000125
#
# Epoch: 133
# Loss: 0.12349512334913015, , Learning Rate: 0.000125
#
# Epoch: 134
# Loss: 0.12911984976381063, , Learning Rate: 0.000125
#
# Epoch: 135
# Loss: 0.12500797770917416, , Learning Rate: 0.000125
#
# Epoch: 136
# Loss: 0.12622445542365313, , Learning Rate: 0.000125
#
# Epoch: 137
# Loss: 0.1280958103016019, , Learning Rate: 6.25e-05
#
# Epoch: 138
# Loss: 0.12307291012257338, , Learning Rate: 6.25e-05
#
# Epoch: 139
# Loss: 0.12644664850085974, , Learning Rate: 6.25e-05
#
# Epoch: 140
# prior term: -2.906
# delta_prob: -2.780
# prior term: -2.900
# delta_prob: -2.747
# prior term: -2.921
# delta_prob: -2.748
# prior term: -2.887
# delta_prob: -2.852
# Loss: 0.12215131428092718, , Learning Rate: 6.25e-05
#
# Epoch: 141
# Loss: 0.12464444432407618, , Learning Rate: 6.25e-05
#
# Epoch: 142
# Loss: 0.12027486180886626, , Learning Rate: 6.25e-05
#
# Epoch: 143
# Loss: 0.11984649021178484, , Learning Rate: 6.25e-05
#
# Epoch: 144
# Loss: 0.12192076724022627, , Learning Rate: 6.25e-05
#
# Epoch: 145
# Loss: 0.119228795170784, , Learning Rate: 6.25e-05
#
# Epoch: 146
# Loss: 0.12271146755665541, , Learning Rate: 6.25e-05
#
# Epoch: 147
# Loss: 0.11908101942390203, , Learning Rate: 6.25e-05
#
# Epoch: 148
# Loss: 0.11740815453231335, , Learning Rate: 6.25e-05
#
# Epoch: 149
# Loss: 0.12068756390362978, , Learning Rate: 6.25e-05
#
# Epoch: 150
# prior term: -2.910
# delta_prob: -2.784
# prior term: -2.900
# delta_prob: -2.757
# prior term: -2.916
# delta_prob: -2.748
# prior term: -2.884
# delta_prob: -2.839
# Loss: 0.12017626035958529, , Learning Rate: 6.25e-05

# %% [markdown]
# ## 6. Model Evaluation/ Visualization

# %%
# Sample Function
@torch.no_grad()
def sample(model, num_samples, t_0, t_end, solver, nb_steps, device, dim_data=2):
    model.eval()
    
    z_0 = torch.randn(num_samples, dim_data, device=device)
    step_size = (t_end - t_0) / nb_steps
    
    def dynamics(y, t):
        return model.net(y, t)
    
    y_end, _ = solver(dynamics, z_0, t_0, nb_steps, step_size)
    return y_end, z_0

# %% [markdown]
# ### 6.1 Circle Model Evaluation

# %%
# Evaluation Circle
# create samples
samples_circle, gauss_points_circle = sample(model_circle, 1000, t_start, t_end, solver, 5000, device)

# make numpy arrays for plotting
samples_np_circle = samples_circle.cpu().numpy()       # shape (1000, 2)
gauss_np_circle = gauss_points_circle.cpu().numpy()    # shape (1000, 2)

# %%
# Plot
fig, ax = plt.subplots(1, 3, figsize=(23, 7))

# Start Distribution
ax[0].scatter(gauss_np_circle[:, 0], gauss_np_circle[:, 1], s=1)
ax[0].set_title("Prior samples (Gauss)")
ax[0].set_xlabel("x-cord")
ax[0].set_ylabel("y-cord")

# Learned Distribution
ax[1].scatter(samples_np_circle[:, 0], samples_np_circle[:, 1], s=1)
ax[1].set_title("Model samples (should be circles)")
ax[1].set_xlabel("x-cord")
ax[1].set_ylabel("y-cord")

# Train Loss
ax[2].plot(range(1, len(train_history_circle)+1), train_history_circle)
ax[2].set_title("Train History")
ax[2].set_ylabel("Loss")
ax[2].set_xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %% [markdown]
# ### 6.2 Moon Model Evalutaion

# %%
# Evaluation Moon
# create samples
samples_moon, gauss_points_moon = sample(model_moon, 1000, t_start, t_end, solver, 5000, device)

# make numpy arrays for plotting
samples_np_moon = samples_moon.cpu().numpy()       # shape (1000, 2)
gauss_np_moon = gauss_points_moon.cpu().numpy()    # shape (1000, 2)

# %%
# Plot Moon
fig, ax = plt.subplots(1, 3, figsize=(23, 7))

# Start Distribution
ax[0].scatter(gauss_np_moon[:, 0], gauss_np_moon[:, 1], s=1)
ax[0].set_title("Prior samples (Gauss)")
ax[0].set_xlabel("x-cord")
ax[0].set_ylabel("y-cord")

# Learned Distribution
ax[1].scatter(samples_np_moon[:, 0], samples_np_moon[:, 1], s=1)
ax[1].set_title("Model samples (should be moons)")
ax[1].set_xlabel("x-cord")
ax[1].set_ylabel("y-cord")

# Train Loss
ax[2].plot(range(1, len(train_history_moon)+1), train_history_moon)
ax[2].set_title("Train History")
ax[2].set_ylabel("Loss")
ax[2].set_xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')
